# %% [markdown]
# <a href="https://colab.research.google.com/github/fabio-sv/learning-python/blob/main/teste_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Texto

# %%
valor =  10;

print(valor);
# Out:
# 10
